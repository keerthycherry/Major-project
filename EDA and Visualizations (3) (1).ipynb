# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df_test=pd.read_csv(r'C:\Users\KeerthyCherry\Downloads\weatherAUS.csv')
df_test.tail(10)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145450  16-06-2017    Uluru      5.2     24.3       0.0          NaN
# 145451  17-06-2017    Uluru      6.4     23.4       0.0          NaN
# 145452  18-06-2017    Uluru      8.0     20.7       0.0          NaN
# 145453  19-06-2017    Uluru      7.4     20.6       0.0          NaN
# 145454  20-06-2017    Uluru      3.5     21.8       0.0          NaN
# 145455  21-06-2017    Uluru      2.8     23.4       0.0          NaN
# 145456  22-06-2017    Uluru      3.6     25.3       0.0          NaN
# 145457  23-06-2017    Uluru      5.4     26.9       0.0          NaN
# 145458  24-06-2017    Uluru      7.8     27.0       0.0          NaN
# 145459  25-06-2017    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145450       NaN           E           24.0         SE  ...        53.0
# ...

# %%
#info of data
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
# shape of data:
print(f'Number of columns: { df_test.shape[1]} and Number of rows: {df_test.shape[0]}')
# Out:
# Number of columns: 23 and Number of rows: 145460

# %%
# statistical info of dataset
df_test.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        143975.0    12.194034   6.398495   -8.5     7.6    12.0
# MaxTemp        144199.0    23.221348   7.119049   -4.8    17.9    22.6
# Rainfall       142199.0     2.360918   8.478060    0.0     0.0     0.0
# Evaporation     82670.0     5.468232   4.193704    0.0     2.6     4.8
# Sunshine        75625.0     7.611178   3.785483    0.0     4.8     8.4
# WindGustSpeed  135197.0    40.035230  13.607062    6.0    31.0    39.0
# WindSpeed9am   143693.0    14.043426   8.915375    0.0     7.0    13.0
# WindSpeed3pm   142398.0    18.662657   8.809800    0.0    13.0    19.0
# Humidity9am    142806.0    68.880831  19.029164    0.0    57.0    70.0
# Humidity3pm    140953.0    51.539116  20.795902    0.0    37.0    52.0
# Pressure9am    130395.0  1017.649940   7.106530  980.5  1012.9  1017.6
# Pressure3pm    130432.0  1015.255889   7.037414  977.1  1010.4  1015.2
# ...

# %%
df_test["RainTomorrow"].value_counts().plot(kind="bar", color=["lightblue", "salmon"]);

# %%
fig, ax = plt.subplots(figsize=(10,7))

ax.scatter(df_test.MaxTemp,
            df_test.Rainfall,
            color=["violet"])
plt.title("MaxTemp vs Rainfall")
plt.ylabel("Rainfall")
plt.xlabel("MaxTemp");

# %%
fig, ax = plt.subplots(figsize=(10,7))

ax.scatter(df_test.MinTemp,
            df_test.Rainfall,
            color=["green"])
plt.title("MinTemp vs Rainfall")
plt.ylabel("Rainfall")
plt.xlabel("MainTemp");

# %%
fig, ax = plt.subplots(figsize=(10,6))

ax.scatter(df_test.Date[:1000],
           df_test.Rainfall[:1000],
           color=["blue"])
plt.title("Date vs Rainfall")
plt.ylabel("Rainfall")
plt.xlabel("Date");

# %%
fig, ax = plt.subplots(figsize=(7,7))

ax.scatter(df_test.Date[:1000],
           df_test.WindGustSpeed[:1000],
           color=["blue"])
plt.title("WindGustSpeed by Date")
plt.ylabel("WindGustSpeed")
plt.xlabel("Date");

# %%
fig, ax = plt.subplots(figsize=(7,7))

ax.scatter(df_test.Date[:1000],
           df_test.Rainfall[:1000],
           color=["darkred"])
plt.title("Rainfall by Date")
plt.ylabel("Rainfall")
plt.xlabel("Date");

# %%
fig,(ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(9,7),
                             sharex=True)

# Scatter plot with WindSpeed9am
ax0.scatter(df_test.Date[:1000],
            df_test.WindSpeed9am[:1000],
            color="teal");

ax0.set(title="WindSpeed9am vs Date",
        xlabel="date",
        ylabel="WindSpeed9am")

# Scatter plot with WindSpeed3pm
ax1.scatter(df_test.Date[:1000],
            df_test.WindSpeed3pm[:1000],
            color="red")

ax1.set(title="WindSpeed3pm vs Date",
        xlabel="date",
        ylabel="WindSpeed3pm");

# %%
fig,(ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10,8),
                             sharex=True)

# Scatter plot with Humidity9am
ax0.scatter(df_test.Date[:1000],
            df_test.Humidity9am[:1000],
            color="teal");
ax0.set(title="Humidity9am vs Date",
        xlabel="date",
        ylabel="Humidity9am")

# Scatter plot with Humidity3pm
ax1.scatter(df_test.Date[:1000],
            df_test.Humidity3pm[:1000],
            color="blue")

ax1.set(title="Humidity3pm vs Date",
        xlabel="date",
        ylabel="Humidity3pm");

# %%
#From this we can infer that Humdity is lowest at January and starts increasing from February till August it is at it's peak on July and then from September to December it starts falling

# %%
fig,(ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10,8),
                             sharex=True)

# Scatter plot with Pressure9am
ax0.scatter(df_test.Date[:1000],
            df_test.Pressure9am[:1000],
            color="green");

ax0.set(title="Pressure9am vs Date",
        xlabel="date",
        ylabel="Pressure9am")

# Scatter plot with Pressure3pm
ax1.scatter(df_test.Date[:1000],
            df_test.Pressure3pm[:1000],
            color="violet")

ax1.set(title="Pressure3pm vs Date",
        xlabel="date",
        ylabel="Pressure3pm");

# %%
fig,(ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10,8),
                             sharex=True)

# Scatter plot with Temp9am
ax0.scatter(df_test.Date[:1000],
            df_test.Temp9am[:1000],
            color="navy");

ax0.set(title="Temp9am vs Date",
        xlabel="date",
        ylabel="Temp9am")

# Scatter plot with Temp3pm
ax1.scatter(df_test.Date[:1000],
            df_test.Temp3pm[:1000],
            color="firebrick")

ax1.set(title="Temp3pm vs Date",
        xlabel="date",
        ylabel="Temp3pm");

# %%
#As Australia lies in the Southern Hemisphere the Summer Season is from December to February and Winter is 
from June to August so we can see high temps during summer and low during winter

# %%
fig,(ax0,ax1) = plt.subplots(nrows=2,
                             ncols=1,
                             figsize=(10,8),
                             sharex=True)

# Scatter plot with Maxtemp
ax0.scatter(df_test.Date[:1000],
            df_test.MaxTemp[:1000],
            color="teal");

ax0.set(title="Maxtemp vs Date",
        xlabel="date",
        ylabel="Maxtemp")

# Scatter plot with MinTemp
ax1.scatter(df_test.Date[:1000],
            df_test.MinTemp[:1000],
            color="firebrick")

ax1.set(title="MinTemp vs Date",
        xlabel="date",
        ylabel="MinTemp");

# %%
#from this we can conclude that During Summer

#maximum MaxTemp is over 45 degrees
#maximum MinTemp is over 25 degrees
#minimum MaxTemp is between 20-30 degrees
#minimum MinTemp is between 5-15 degrees

#During Winter

#maximum MaxTemp is between 20-25 degrees
#maximum MinTemp is between 5-10 degrees
#minimum MaxTemp is just under 10 degrees
#minimum MinTemp is under 0 degrees

# %%
#visualizing missing values
#matrix
import missingno as msno
msno.matrix(df_test)
# Out:
# <AxesSubplot:>

# %%
#heatmap
msno.heatmap(df_test)
# Out:
# <AxesSubplot:>

# %%
#bar graph
msno.bar(df_test)
# Out:
# <AxesSubplot:>

# %%
#line plot
df_test.plot.line()
# Out:
# <AxesSubplot:>

# %%
#histogram
df_test.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
#boxplot
boxplot=df_test.boxplot(figsize=(7,7),rot=90,fontsize="10")

# %%
#Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually.
#This step is very important especially when we arrive at modeling the data in order to apply Machine learning. 
#Plotting in EDA consists of Histograms, Box plot, line plot,bar charts and many more.
#In above file we had visualized missing values through matrix,bar chart and heatmap.These plottings are done by using Missingno library.
#Using pandas we had visualized data through boxplot,histogram,line plot.
#Every column is visualized through scatter plot.
