# %%
import pandas as pd
import numpy as np
df_test=pd.read_csv(r'D:\MajorProject\weatherAUS.csv')
df_test.tail(10)
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 145450  2017-06-16    Uluru      5.2     24.3       0.0          NaN
# 145451  2017-06-17    Uluru      6.4     23.4       0.0          NaN
# 145452  2017-06-18    Uluru      8.0     20.7       0.0          NaN
# 145453  2017-06-19    Uluru      7.4     20.6       0.0          NaN
# 145454  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 145455  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 145456  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 145457  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 145458  2017-06-24    Uluru      7.8     27.0       0.0          NaN
# 145459  2017-06-25    Uluru     14.9      NaN       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 145450       NaN           E           24.0         SE  ...        53.0
# ...

# %%
# Info of data
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
# shape of data:
print(f'Number of columns: { df_test.shape[0]} and Number of rows: {df_test.shape[1]}')
# Out:
# Number of columns: 145460 and Number of rows: 23

# %%
# Checking for null values
df_test.isna().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
# statistical info of dataset
df_test.describe().T
# Out:
#                   count         mean        std    min     25%     50%  \
# MinTemp        143975.0    12.194034   6.398495   -8.5     7.6    12.0
# MaxTemp        144199.0    23.221348   7.119049   -4.8    17.9    22.6
# Rainfall       142199.0     2.360918   8.478060    0.0     0.0     0.0
# Evaporation     82670.0     5.468232   4.193704    0.0     2.6     4.8
# Sunshine        75625.0     7.611178   3.785483    0.0     4.8     8.4
# WindGustSpeed  135197.0    40.035230  13.607062    6.0    31.0    39.0
# WindSpeed9am   143693.0    14.043426   8.915375    0.0     7.0    13.0
# WindSpeed3pm   142398.0    18.662657   8.809800    0.0    13.0    19.0
# Humidity9am    142806.0    68.880831  19.029164    0.0    57.0    70.0
# Humidity3pm    140953.0    51.539116  20.795902    0.0    37.0    52.0
# Pressure9am    130395.0  1017.649940   7.106530  980.5  1012.9  1017.6
# Pressure3pm    130432.0  1015.255889   7.037414  977.1  1010.4  1015.2
# ...

# %%
# Identifying Continuous and Categorical Columns
cat=[]
cont = []

for i in df_test.columns:
    if df_test[i].dtype =="object":
        cat.append(i)
        
    else:
        cont.append(i)

print("Categorical:",cat)
print("Continuous:", cont)
# Out:
# Categorical: ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']
# Continuous: ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
#visualizing missing values
import missingno as msno
msno.matrix(df_test)
# Out:
# <AxesSubplot:>

# %%
msno.heatmap(df_test)
# Out:
# <AxesSubplot:>

# %%
#percentage of null values in the data set
(df_test.isnull().sum()/len(df_test))*100
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
for i in range(0,145460):
    count_nan = df_test.loc[[i]].isna().sum().sum()
    if count_nan > 12 :
        df_test = df_test.drop(index=i)
df_test = df_test.reset_index(drop=True)
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144171 entries, 0 to 144170
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           144171 non-null  object
#  1   Location       144171 non-null  object
#  2   MinTemp        143760 non-null  float64
#  3   MaxTemp        143831 non-null  float64
#  4   Rainfall       141890 non-null  float64
#  5   Evaporation    82094 non-null   float64
#  6   Sunshine       75056 non-null   float64
#  7   WindGustDir    134574 non-null  object
#  8   WindGustSpeed  134636 non-null  float64
#  9   WindDir9am     134361 non-null  object
#  10  WindDir3pm     140639 non-null  object
#  11  WindSpeed9am   143089 non-null  float64
#  12  WindSpeed3pm   141793 non-null  float64
#  13  Humidity9am    142650 non-null  float64
#  14  Humidity3pm    140791 non-null  float64
#  15  Pressure9am    130335 non-null  float64
# ...

# %%
# filling the missing values for continuous variables with mean
df_test["MinTemp"]= df_test["MinTemp"].fillna(df_test["MinTemp"].mean())
df_test["MaxTemp"]= df_test["MaxTemp"].fillna(df_test["MaxTemp"].mean())
df_test["Evaporation"]= df_test["Evaporation"].fillna(df_test["Evaporation"].mean())
df_test["Sunshine"]= df_test["Sunshine"].fillna(df_test["Sunshine"].mean())
df_test["WindGustSpeed"]= df_test["WindGustSpeed"].fillna(df_test["WindGustSpeed"].mean())
df_test["Rainfall"]= df_test["Rainfall"].fillna(df_test["Rainfall"].mean())
df_test["WindSpeed9am"]= df_test["WindSpeed9am"].fillna(df_test["WindSpeed9am"].mean())
df_test["WindSpeed3pm"]= df_test["WindSpeed3pm"].fillna(df_test["WindSpeed3pm"].mean())
df_test["Humidity9am"]= df_test["Humidity9am"].fillna(df_test["Humidity9am"].mean())
df_test["Humidity3pm"]= df_test["Humidity3pm"].fillna(df_test["Humidity3pm"].mean())
df_test["Pressure9am"]= df_test["Pressure9am"].fillna(df_test["Pressure9am"].mean())
df_test["Pressure3pm"]= df_test["Pressure3pm"].fillna(df_test["Pressure3pm"].mean())
df_test["Cloud9am"]= df_test["Cloud9am"].fillna(df_test["Cloud9am"].mean())
df_test["Cloud3pm"]= df_test["Cloud3pm"].fillna(df_test["Cloud3pm"].mean())
df_test["Temp9am"]= df_test["Temp9am"].fillna(df_test["Temp9am"].mean())
df_test["Temp3pm"]= df_test["Temp3pm"].fillna(df_test["Temp3pm"].mean())

# %%
#Filling the missing values for categorical variables with mode
df_test['RainToday']=df_test['RainToday'].fillna(df_test['RainToday'].mode()[0])
df_test['RainTomorrow']=df_test['RainTomorrow'].fillna(df_test['RainTomorrow'].mode()[0])
df_test['WindDir9am'] = df_test['WindDir9am'].fillna(df_test['WindDir9am'].mode()[0])
df_test['WindGustDir'] = df_test['WindGustDir'].fillna(df_test['WindGustDir'].mode()[0])
df_test['WindDir3pm'] = df_test['WindDir3pm'].fillna(df_test['WindDir3pm'].mode()[0])
df_test['Location'] = df_test['Location'].fillna(df_test['Location'].mode()[0])

# %%
# again checking for null values
(df_test.isnull().sum()/len(df_test))*100
# Out:
# Date             0.0
# Location         0.0
# MinTemp          0.0
# MaxTemp          0.0
# Rainfall         0.0
# Evaporation      0.0
# Sunshine         0.0
# WindGustDir      0.0
# WindGustSpeed    0.0
# WindDir9am       0.0
# WindDir3pm       0.0
# WindSpeed9am     0.0
# WindSpeed3pm     0.0
# Humidity9am      0.0
# Humidity3pm      0.0
# Pressure9am      0.0
# Pressure3pm      0.0
# Cloud9am         0.0
# Cloud3pm         0.0
# Temp9am          0.0
# Temp3pm          0.0
# RainToday        0.0
# RainTomorrow     0.0
# dtype: float64

# %%
df_test=df_test.round()
df_test
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.0     23.0       1.0          5.0
# 1       2008-12-02   Albury      7.0     25.0       0.0          5.0
# 2       2008-12-03   Albury     13.0     26.0       0.0          5.0
# 3       2008-12-04   Albury      9.0     28.0       0.0          5.0
# 4       2008-12-05   Albury     18.0     32.0       1.0          5.0
# ...            ...      ...      ...      ...       ...          ...
# 144166  2017-06-21    Uluru      3.0     23.0       0.0          5.0
# 144167  2017-06-22    Uluru      4.0     25.0       0.0          5.0
# 144168  2017-06-23    Uluru      5.0     27.0       0.0          5.0
# 144169  2017-06-24    Uluru      8.0     27.0       0.0          5.0
# 144170  2017-06-25    Uluru     15.0     23.0       0.0          5.0
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
print(pd.unique(df_test['WindGustDir']))
print(pd.unique(df_test['WindDir9am']))
print(pd.unique(df_test['WindDir3pm']))
print(pd.unique(df_test['Location']))
# Out:
# ['W' 'WNW' 'WSW' 'NE' 'NNW' 'N' 'NNE' 'SW' 'ENE' 'SSE' 'S' 'NW' 'SE' 'ESE'
#  'E' 'SSW']
# ['W' 'NNW' 'SE' 'ENE' 'SW' 'SSE' 'S' 'NE' 'N' 'SSW' 'WSW' 'ESE' 'E' 'NW'
#  'WNW' 'NNE']
# ['WNW' 'WSW' 'E' 'NW' 'W' 'SSE' 'ESE' 'ENE' 'NNW' 'SSW' 'SW' 'SE' 'N' 'S'
#  'NNE' 'NE']
# ['Albury' 'BadgerysCreek' 'Cobar' 'CoffsHarbour' 'Moree' 'Newcastle'
#  'NorahHead' 'NorfolkIsland' 'Penrith' 'Richmond' 'Sydney' 'SydneyAirport'
#  'WaggaWagga' 'Williamtown' 'Wollongong' 'Canberra' 'Tuggeranong'
#  'MountGinini' 'Ballarat' 'Bendigo' 'Sale' 'MelbourneAirport' 'Melbourne'
#  'Mildura' 'Nhil' 'Portland' 'Watsonia' 'Dartmoor' 'Brisbane' 'Cairns'
#  'GoldCoast' 'Townsville' 'Adelaide' 'MountGambier' 'Nuriootpa' 'Woomera'
#  'Albany' 'Witchcliffe' 'PearceRAAF' 'PerthAirport' 'Perth' 'SalmonGums'
#  'Walpole' 'Hobart' 'Launceston' 'AliceSprings' 'Darwin' 'Katherine'
#  'Uluru']

# %%
pd.options.mode.chained_assignment = None
directions={'SW':0, 'SSE':1, 'NNW':2, 'WSW':3, 'WNW':4, 'S':5, 'ENE':6,'N':7,'NW':8,'SE':9, 'NNE':10, 'ESE':11, 'E':12 ,'NE':13,
 'SSW':14, 'W':15}
m=list(df_test['WindGustDir'])
for i in range(0,len(m)):
    a=directions.get(m[i])
    m[i]=a
df_test['WindGustDir']=m

# %%
n=list(df_test['WindDir9am'])
o=list(df_test['WindDir3pm'])
for i in range(0,len(n)):
    a=directions.get(n[i])
    b=directions.get(o[i])
    n[i]=a
    o[i]=b
df_test['WindDir9am']=n
df_test['WindDir3pm']=o

# %%
d={'Yes':1,'No':0}
r=list(df_test['RainTomorrow'])
for i in range(0,len(r)):
    a=d.get(r[i])
    r[i]=a
df_test['RainTomorrow']=r
print(pd.unique(df_test['RainTomorrow']))
# Out:
# [0 1]

# %%
z=list(pd.unique(df_test['Location']))
print(len(z))
res_dct = {z[i]: i for i in range(49)}
s=list(df_test['Location'])
for i in range(0,len(s)):
    a=res_dct.get(s[i])
    s[i]=a
df_test['Location']=list(s)
df_test.tail(10)
# Out:
# 49
#               Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 144161  2017-06-16        48      5.0     24.0       0.0          5.0
# 144162  2017-06-17        48      6.0     23.0       0.0          5.0
# 144163  2017-06-18        48      8.0     21.0       0.0          5.0
# 144164  2017-06-19        48      7.0     21.0       0.0          5.0
# 144165  2017-06-20        48      4.0     22.0       0.0          5.0
# 144166  2017-06-21        48      3.0     23.0       0.0          5.0
# 144167  2017-06-22        48      4.0     25.0       0.0          5.0
# 144168  2017-06-23        48      5.0     27.0       0.0          5.0
# 144169  2017-06-24        48      8.0     27.0       0.0          5.0
# 144170  2017-06-25        48     15.0     23.0       0.0          5.0
#
#         Sunshine  WindGustDir  WindGustSpeed  WindDir9am  ...  Humidity9am  \
# 144161       8.0           12           24.0           9  ...         53.0
# ...

# %%
d={'Yes':1,'No':0}
r=list(df_test['RainToday'])
for i in range(0,len(r)):
    a=d.get(r[i])
    r[i]=a
df_test['RainToday']=r

# %%
rain=df_test[['Location','MinTemp','MaxTemp','Rainfall','Evaporation','Sunshine','WindGustDir','WindGustSpeed',
'WindDir9am','WindDir3pm','WindSpeed9am','WindSpeed3pm','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm'       
,'Cloud9am','Cloud3pm','Temp9am','Temp3pm','RainToday','RainTomorrow']]
rain
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0              0     13.0     23.0       1.0          5.0       8.0
# 1              0      7.0     25.0       0.0          5.0       8.0
# 2              0     13.0     26.0       0.0          5.0       8.0
# 3              0      9.0     28.0       0.0          5.0       8.0
# 4              0     18.0     32.0       1.0          5.0       8.0
# ...          ...      ...      ...       ...          ...       ...
# 144166        48      3.0     23.0       0.0          5.0       8.0
# 144167        48      4.0     25.0       0.0          5.0       8.0
# 144168        48      5.0     27.0       0.0          5.0       8.0
# 144169        48      8.0     27.0       0.0          5.0       8.0
# 144170        48     15.0     23.0       0.0          5.0       8.0
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  \
# ...

# %%
from scipy import stats
print('Shape of DataFrame Before Removing Outliers', rain.shape )
rain=rain[(np.abs(stats.zscore(rain)) < 3).all(axis=1)]
print('Shape of DataFrame After Removing Outliers', rain.shape )
# Out:
# Shape of DataFrame Before Removing Outliers (144171, 22)
# Shape of DataFrame After Removing Outliers (135155, 22)

# %%
data=rain[['Location','MinTemp','MaxTemp','Rainfall','Evaporation','Sunshine','WindGustDir','WindGustSpeed',
'WindDir9am','WindDir3pm','WindSpeed9am','WindSpeed3pm','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm'       
,'Cloud9am','Cloud3pm','Temp9am','Temp3pm','RainToday']]
rain
# Out:
#         Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0              0     13.0     23.0       1.0          5.0       8.0
# 1              0      7.0     25.0       0.0          5.0       8.0
# 2              0     13.0     26.0       0.0          5.0       8.0
# 3              0      9.0     28.0       0.0          5.0       8.0
# 4              0     18.0     32.0       1.0          5.0       8.0
# ...          ...      ...      ...       ...          ...       ...
# 144166        48      3.0     23.0       0.0          5.0       8.0
# 144167        48      4.0     25.0       0.0          5.0       8.0
# 144168        48      5.0     27.0       0.0          5.0       8.0
# 144169        48      8.0     27.0       0.0          5.0       8.0
# 144170        48     15.0     23.0       0.0          5.0       8.0
#
#         WindGustDir  WindGustSpeed  WindDir9am  WindDir3pm  ...  Humidity9am  \
# ...

# %%
target=rain[['RainTomorrow']]
target
# Out:
#         RainTomorrow
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 144166             0
# 144167             0
# 144168             0
# 144169             0
# 144170             0
#
# [135155 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
from matplotlib import pyplot

# feature selection
def select_features(X_train, y_train, X_test):
	# configure to select all features
	fs = SelectKBest(score_func=f_classif, k='all')
	# learn relationship from training data
	fs.fit(X_train, y_train)
	# transform train input data
	X_train_fs = fs.transform(X_train)
	# transform test input data
	X_test_fs = fs.transform(X_test)
	return X_train_fs, X_test_fs, fs


# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(data,target, test_size=0.33, random_state=1)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)
# what are scores for the features
for i in range(len(fs.scores_)):
	print('Feature %d: %f' % (i, fs.scores_[i]))
# plot the scores
pyplot.bar([i for i in range(len(fs.scores_))], fs.scores_)
pyplot.show()
# Out:
# c:\users\naga jahnavi k\appdata\local\programs\python\python39\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# Feature 0: 2.166289
# Feature 1: 616.528439
# Feature 2: 2011.503442
# Feature 3: 6346.142801
# Feature 4: 872.669460
# Feature 5: 9686.263141
# Feature 6: 3.517772
# Feature 7: 3532.917962
# Feature 8: 39.862692
# Feature 9: 6.083828
# Feature 10: 363.021992
# Feature 11: 315.264126
# Feature 12: 5306.782123
# Feature 13: 19397.285910
# Feature 14: 4220.895960
# Feature 15: 3517.967219
# Feature 16: 5296.731418
# Feature 17: 7753.618421
# Feature 18: 35.445108
# Feature 19: 3010.005040
# Feature 20: 7457.499429

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 135155 entries, 0 to 144170
# Data columns (total 21 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       135155 non-null  int64
#  1   MinTemp        135155 non-null  float64
#  2   MaxTemp        135155 non-null  float64
#  3   Rainfall       135155 non-null  float64
#  4   Evaporation    135155 non-null  float64
#  5   Sunshine       135155 non-null  float64
#  6   WindGustDir    135155 non-null  int64
#  7   WindGustSpeed  135155 non-null  float64
#  8   WindDir9am     135155 non-null  int64
#  9   WindDir3pm     135155 non-null  int64
#  10  WindSpeed9am   135155 non-null  float64
#  11  WindSpeed3pm   135155 non-null  float64
#  12  Humidity9am    135155 non-null  float64
#  13  Humidity3pm    135155 non-null  float64
#  14  Pressure9am    135155 non-null  float64
#  15  Pressure3pm    135155 non-null  float64
#  16  Cloud9am       135155 non-null  float64
# ...

# %%
# From the feature scores, we take the top ten features: 'Rainfall','Sunshine','WindGustSpeed','Humidity9am','Humidity3pm','Pressure9am'
#,'Pressure3pm','Cloud9am','Cloud3pm','Temp3pm','RainToday'

# %%
X_train_2=X_train[['Rainfall','Sunshine','WindGustSpeed','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','Temp3pm','RainToday']]

# %%
X_train_2
# Out:
#         Rainfall  Sunshine  WindGustSpeed  Humidity9am  Humidity3pm  \
# 19809        1.0       8.0           61.0         82.0         68.0
# 4904         0.0       8.0           17.0         82.0         47.0
# 23153        1.0       7.0           35.0         58.0         62.0
# 117692       0.0       6.0           33.0         66.0         55.0
# 118806       0.0      10.0           43.0         48.0         24.0
# ...          ...       ...            ...          ...          ...
# 78349        0.0      10.0           37.0         84.0         34.0
# 116573       3.0       7.0           26.0         91.0         60.0
# 53316        6.0       8.0           28.0         99.0         94.0
# 5336         0.0       8.0           26.0        100.0         45.0
# 136404       0.0      11.0           31.0         53.0         15.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp3pm  RainToday
# 19809        1009.0       1006.0       4.0       5.0     25.0          0
# ...

# %%
X_test_2 = X_test[['Rainfall','Sunshine','WindGustSpeed','Humidity9am','Humidity3pm','Pressure9am','Pressure3pm','Cloud9am','Cloud3pm','Temp3pm','RainToday']]

# %%
X_test_2
# Out:
#         Rainfall  Sunshine  WindGustSpeed  Humidity9am  Humidity3pm  \
# 97327        7.0       8.0           44.0         90.0         44.0
# 72230        0.0       8.0           31.0         70.0         31.0
# 35277        0.0       8.0           39.0         67.0         75.0
# 48788        0.0       8.0           43.0         67.0         64.0
# 62336        0.0       2.0           50.0         61.0         92.0
# ...          ...       ...            ...          ...          ...
# 105022       2.0       2.0           69.0         98.0         87.0
# 122103       0.0      11.0           37.0         45.0         36.0
# 92913        0.0       6.0           56.0         55.0         60.0
# 114347       0.0      10.0           35.0         49.0         35.0
# 39176        0.0       7.0           37.0         79.0         65.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp3pm  RainToday
# 97327        1014.0       1015.0       4.0       5.0     16.0          1
# ...

# %%
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
def run_randomForest(X_train, X_test, y_train, y_test):
    clf = RandomForestClassifier(n_estimators=100, random_state=0, n_jobs=-1)
    clf.fit(X_train, y_train.values.ravel())
    y_pred = clf.predict(X_test)
    accuracyScore=accuracy_score(y_test,y_pred)
    print('Accuracy: ', accuracy_score(y_test, y_pred))
    print('Accuracy in percentage: ',round(accuracyScore*100),'%')

# %%
# %%time
run_randomForest(X_train_2, X_test_2, y_train, y_test)
# Out:
# Accuracy:  0.851508900946146
# Accuracy in percentage:  85 %
# Wall time: 8.66 s

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train_2,y_train.values.ravel())
y_pred=lr.predict(X_test_2)
accuracyScore=accuracy_score(y_test,y_pred)
print('Accuracy score: ',accuracyScore)
print('Accuracy in percentage: ',round(accuracyScore*100),'%')
# Out:
# Accuracy score:  0.8409264158557912
# Accuracy in percentage:  84 %
# c:\users\naga jahnavi k\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
